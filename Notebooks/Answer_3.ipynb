# %%
import pandas as pd
import numpy as np
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                  R_fighter       B_fighter               Referee        date  \
# 0             Henry Cejudo   Marlon Moraes          Marc Goddard  2019-06-08
# 1     Valentina Shevchenko     Jessica Eye       Robert Madrigal  2019-06-08
# 2            Tony Ferguson  Donald Cerrone       Dan Miragliotta  2019-06-08
# 3            Jimmie Rivera        Petr Yan       Kevin MacDonald  2019-06-08
# 4              Tai Tuivasa   Blagoy Ivanov       Dan Miragliotta  2019-06-08
# ...                    ...             ...                   ...         ...
# 5139        Gerard Gordeau    Kevin Rosier  Joao Alberto Barreto  1993-11-12
# 5140          Ken Shamrock   Patrick Smith  Joao Alberto Barreto  1993-11-12
# 5141          Royce Gracie   Art Jimmerson  Joao Alberto Barreto  1993-11-12
# 5142          Kevin Rosier    Zane Frazier  Joao Alberto Barreto  1993-11-12
# 5143        Gerard Gordeau      Teila Tuli  Joao Alberto Barreto  1993-11-12
#
#                     location Winner  title_bout       weight_class  \
# 0     Chicago, Illinois, USA    Red        True       Bantamweight
# 1     Chicago, Illinois, USA    Red        True  Women's Flyweight
# 2     Chicago, Illinois, USA    Red       False        Lightweight
# 3     Chicago, Illinois, USA   Blue       False       Bantamweight
# 4     Chicago, Illinois, USA   Blue       False        Heavyweight
# ...                      ...    ...         ...                ...
# 5139   Denver, Colorado, USA    Red       False        Open Weight
# 5140   Denver, Colorado, USA    Red       False        Open Weight
# 5141   Denver, Colorado, USA    Red       False        Open Weight
# 5142   Denver, Colorado, USA    Red       False        Open Weight
# 5143   Denver, Colorado, USA    Red       False        Open Weight
#
#       no_of_rounds  B_current_lose_streak  ...  R_win_by_KO/TKO  \
# 0                5                    0.0  ...              2.0
# 1                5                    0.0  ...              0.0
# 2                3                    0.0  ...              3.0
# 3                3                    0.0  ...              1.0
# 4                3                    0.0  ...              2.0
# ...            ...                    ...  ...              ...
# 5139             1                    0.0  ...              1.0
# 5140             1                    0.0  ...              0.0
# 5141             1                    0.0  ...              0.0
# 5142             1                    0.0  ...              0.0
# 5143             1                    0.0  ...              0.0
#
#       R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  \
# 0                     0.0                           0.0     8.0  Orthodox
# 1                     2.0                           0.0     5.0  Southpaw
# 2                     6.0                           1.0    14.0  Orthodox
# 3                     0.0                           0.0     6.0  Orthodox
# 4                     0.0                           0.0     3.0  Southpaw
# ...                   ...                           ...     ...       ...
# 5139                  0.0                           0.0     1.0  Orthodox
# 5140                  0.0                           0.0     0.0  Orthodox
# 5141                  0.0                           0.0     0.0  Southpaw
# 5142                  0.0                           0.0     0.0  Orthodox
# 5143                  0.0                           0.0     0.0  Orthodox
#
#       R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0           162.56       162.56         135.0   31.0   32.0
# 1           165.10       167.64         125.0   32.0   31.0
# 2           180.34       193.04         155.0   36.0   35.0
# 3           162.56       172.72         135.0   26.0   29.0
# 4           187.96       190.50         264.0   32.0   26.0
# ...            ...          ...           ...    ...    ...
# 5139        195.58          NaN         216.0    NaN   34.0
# 5140        185.42       182.88         205.0   30.0   29.0
# 5141        185.42          NaN         175.0   30.0   26.0
# 5142        193.04          NaN         275.0    NaN    NaN
# 5143        195.58          NaN         216.0   24.0   34.0
#
# [5144 rows x 145 columns]

# %%
df["R_eff_STR"] = df.R_avg_TOTAL_STR_landed / df.R_avg_TOTAL_STR_att

# %%
df["B_eff_STR"] = df.B_avg_TOTAL_STR_landed / df.B_avg_TOTAL_STR_att
df
# Out:
#                  R_fighter       B_fighter               Referee        date  \
# 0             Henry Cejudo   Marlon Moraes          Marc Goddard  2019-06-08
# 1     Valentina Shevchenko     Jessica Eye       Robert Madrigal  2019-06-08
# 2            Tony Ferguson  Donald Cerrone       Dan Miragliotta  2019-06-08
# 3            Jimmie Rivera        Petr Yan       Kevin MacDonald  2019-06-08
# 4              Tai Tuivasa   Blagoy Ivanov       Dan Miragliotta  2019-06-08
# ...                    ...             ...                   ...         ...
# 5139        Gerard Gordeau    Kevin Rosier  Joao Alberto Barreto  1993-11-12
# 5140          Ken Shamrock   Patrick Smith  Joao Alberto Barreto  1993-11-12
# 5141          Royce Gracie   Art Jimmerson  Joao Alberto Barreto  1993-11-12
# 5142          Kevin Rosier    Zane Frazier  Joao Alberto Barreto  1993-11-12
# 5143        Gerard Gordeau      Teila Tuli  Joao Alberto Barreto  1993-11-12
#
#                     location Winner  title_bout       weight_class  \
# 0     Chicago, Illinois, USA    Red        True       Bantamweight
# 1     Chicago, Illinois, USA    Red        True  Women's Flyweight
# 2     Chicago, Illinois, USA    Red       False        Lightweight
# 3     Chicago, Illinois, USA   Blue       False       Bantamweight
# 4     Chicago, Illinois, USA   Blue       False        Heavyweight
# ...                      ...    ...         ...                ...
# 5139   Denver, Colorado, USA    Red       False        Open Weight
# 5140   Denver, Colorado, USA    Red       False        Open Weight
# 5141   Denver, Colorado, USA    Red       False        Open Weight
# 5142   Denver, Colorado, USA    Red       False        Open Weight
# 5143   Denver, Colorado, USA    Red       False        Open Weight
#
#       no_of_rounds  B_current_lose_streak  ...  R_win_by_TKO_Doctor_Stoppage  \
# 0                5                    0.0  ...                           0.0
# 1                5                    0.0  ...                           0.0
# 2                3                    0.0  ...                           1.0
# 3                3                    0.0  ...                           0.0
# 4                3                    0.0  ...                           0.0
# ...            ...                    ...  ...                           ...
# 5139             1                    0.0  ...                           0.0
# 5140             1                    0.0  ...                           0.0
# 5141             1                    0.0  ...                           0.0
# 5142             1                    0.0  ...                           0.0
# 5143             1                    0.0  ...                           0.0
#
#       R_wins  R_Stance  R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age  \
# 0        8.0  Orthodox        162.56       162.56         135.0   31.0   32.0
# 1        5.0  Southpaw        165.10       167.64         125.0   32.0   31.0
# 2       14.0  Orthodox        180.34       193.04         155.0   36.0   35.0
# 3        6.0  Orthodox        162.56       172.72         135.0   26.0   29.0
# 4        3.0  Southpaw        187.96       190.50         264.0   32.0   26.0
# ...      ...       ...           ...          ...           ...    ...    ...
# 5139     1.0  Orthodox        195.58          NaN         216.0    NaN   34.0
# 5140     0.0  Orthodox        185.42       182.88         205.0   30.0   29.0
# 5141     0.0  Southpaw        185.42          NaN         175.0   30.0   26.0
# 5142     0.0  Orthodox        193.04          NaN         275.0    NaN    NaN
# 5143     0.0  Orthodox        195.58          NaN         216.0   24.0   34.0
#
#       R_eff_STR  B_eff_STR
# 0      0.531948   0.355422
# 1      0.636605   0.438563
# 2      0.476692   0.506687
# 3      0.432375   0.560582
# 4      0.515748   0.303922
# ...         ...        ...
# 5139   0.600000   0.716981
# 5140        NaN        NaN
# 5141        NaN        NaN
# 5142        NaN        NaN
# 5143        NaN        NaN
#
# [5144 rows x 147 columns]

# %%
df = df.sort_values(by=["R_eff_STR"], ascending=False)
df
# Out:
#              R_fighter        B_fighter               Referee        date  \
# 1193      Keith Berish       Ryan Janes  Todd Ronald Anderson  2016-12-09
# 4168  David Bielkheden     Jess Liaudin         Kevin Mulhall  2008-10-18
# 5068    Gary Goodridge  Jerry Bohlander         John McCarthy  1996-02-16
# 428      Hakeem Dawodu    Austin Arnett          Yves Lavigne  2018-07-28
# 492         Song Kenan    Hector Aldana            Thomas Fan  2018-06-23
# ...                ...              ...                   ...         ...
# 5137     Jason DeLucia    Trent Jenkins  Joao Alberto Barreto  1993-11-12
# 5140      Ken Shamrock    Patrick Smith  Joao Alberto Barreto  1993-11-12
# 5141      Royce Gracie    Art Jimmerson  Joao Alberto Barreto  1993-11-12
# 5142      Kevin Rosier     Zane Frazier  Joao Alberto Barreto  1993-11-12
# 5143    Gerard Gordeau       Teila Tuli  Joao Alberto Barreto  1993-11-12
#
#                                  location Winner  title_bout   weight_class  \
# 1193                Albany, New York, USA   Blue       False   Middleweight
# 4168  Birmingham, England, United Kingdom    Red       False    Lightweight
# 5068                San Juan, Puerto Rico    Red       False    Open Weight
# 428              Calgary, Alberta, Canada    Red       False  Featherweight
# 492                    Kallang, Singapore    Red       False   Welterweight
# ...                                   ...    ...         ...            ...
# 5137                Denver, Colorado, USA    Red       False    Open Weight
# 5140                Denver, Colorado, USA    Red       False    Open Weight
# 5141                Denver, Colorado, USA    Red       False    Open Weight
# 5142                Denver, Colorado, USA    Red       False    Open Weight
# 5143                Denver, Colorado, USA    Red       False    Open Weight
#
#       no_of_rounds  B_current_lose_streak  ...  R_win_by_TKO_Doctor_Stoppage  \
# 1193             3                    0.0  ...                           0.0
# 4168             3                    2.0  ...                           0.0
# 5068             1                    0.0  ...                           0.0
# 428              3                    1.0  ...                           0.0
# 492              3                    0.0  ...                           0.0
# ...            ...                    ...  ...                           ...
# 5137             1                    0.0  ...                           0.0
# 5140             1                    0.0  ...                           0.0
# 5141             1                    0.0  ...                           0.0
# 5142             1                    0.0  ...                           0.0
# 5143             1                    0.0  ...                           0.0
#
#       R_wins  R_Stance  R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age  \
# 1193     0.0  Orthodox        182.88       185.42         205.0   35.0   31.0
# 4168     0.0  Orthodox        177.80       180.34         155.0    NaN   29.0
# 5068     1.0  Orthodox        190.50          NaN         249.0   22.0   30.0
# 428      0.0  Orthodox        172.72       185.42         145.0   26.0   27.0
# 492      1.0  Orthodox        182.88       180.34         170.0   29.0   28.0
# ...      ...       ...           ...          ...           ...    ...    ...
# 5137     0.0  Southpaw        180.34          NaN         190.0    NaN   24.0
# 5140     0.0  Orthodox        185.42       182.88         205.0   30.0   29.0
# 5141     0.0  Southpaw        185.42          NaN         175.0   30.0   26.0
# 5142     0.0  Orthodox        193.04          NaN         275.0    NaN    NaN
# 5143     0.0  Orthodox        195.58          NaN         216.0   24.0   34.0
#
#       R_eff_STR  B_eff_STR
# 1193        1.0        NaN
# 4168        1.0   0.590164
# 5068        1.0   0.818182
# 428         1.0   0.368421
# 492         1.0        NaN
# ...         ...        ...
# 5137        NaN        NaN
# 5140        NaN        NaN
# 5141        NaN        NaN
# 5142        NaN        NaN
# 5143        NaN        NaN
#
# [5144 rows x 147 columns]

# %%
df = df.dropna()
df
# Out:
#               R_fighter          B_fighter           Referee        date  \
# 428       Hakeem Dawodu      Austin Arnett      Yves Lavigne  2018-07-28
# 2961      Gunnar Nelson     Jorge Santiago      Marc Goddard  2013-02-16
# 4361          Nate Diaz    Junior Assuncao  Steve Mazzagatti  2007-09-19
# 4298          Nate Diaz     Alvin Robinson  Steve Mazzagatti  2008-01-23
# 4702       Joe Doerksen       Patrick Cote         Herb Dean  2005-04-16
# ...                 ...                ...               ...         ...
# 3784       Ben Rothwell       Gilbert Yvel      Yves Lavigne  2010-06-12
# 3298       TJ Dillashaw       Walel Watson    Josh Rosenthal  2012-02-15
# 1535      Ian Entwistle    Alejandro Perez    Grant Waterman  2016-04-10
# 3530      Darren Elkins  Michihiro Omigawa      Kevin Dornan  2011-06-11
# 3874  Chris Tuchscherer          Tim Hague    Josh Rosenthal  2010-02-06
#
#                                  location Winner  title_bout   weight_class  \
# 428              Calgary, Alberta, Canada    Red       False  Featherweight
# 2961      London, England, United Kingdom    Red       False   Welterweight
# 4361               Las Vegas, Nevada, USA    Red       False    Lightweight
# 4298               Las Vegas, Nevada, USA    Red       False    Lightweight
# 4702               Las Vegas, Nevada, USA    Red       False   Middleweight
# ...                                   ...    ...         ...            ...
# 3784  Vancouver, British Columbia, Canada    Red       False    Heavyweight
# 3298                 Omaha, Nebraska, USA    Red       False   Bantamweight
# 1535                      Zagreb, Croatia   Blue       False   Bantamweight
# 3530  Vancouver, British Columbia, Canada    Red       False  Featherweight
# 3874               Las Vegas, Nevada, USA    Red       False    Heavyweight
#
#       no_of_rounds  B_current_lose_streak  ...  R_win_by_TKO_Doctor_Stoppage  \
# 428              3                    1.0  ...                           0.0
# 2961             3                    4.0  ...                           0.0
# 4361             3                    0.0  ...                           0.0
# 4298             3                    0.0  ...                           0.0
# 4702             3                    1.0  ...                           0.0
# ...            ...                    ...  ...                           ...
# 3784             3                    1.0  ...                           0.0
# 3298             3                    1.0  ...                           0.0
# 1535             3                    0.0  ...                           0.0
# 3530             3                    3.0  ...                           0.0
# 3874             3                    1.0  ...                           0.0
#
#       R_wins  R_Stance  R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age  \
# 428      0.0  Orthodox        172.72       185.42         145.0   26.0   27.0
# 2961     1.0    Switch        180.34       182.88         170.0   32.0   24.0
# 4361     1.0  Southpaw        182.88       193.04         170.0   26.0   22.0
# 4298     2.0  Southpaw        182.88       193.04         170.0   25.0   22.0
# 4702     0.0  Orthodox        182.88       190.50         185.0   25.0   27.0
# ...      ...       ...           ...          ...           ...    ...    ...
# 3784     0.0  Orthodox        193.04       198.12         265.0   33.0   28.0
# 3298     0.0  Orthodox        167.64       170.18         125.0   27.0   26.0
# 1535     1.0  Orthodox        165.10       162.56         135.0   26.0   29.0
# 3530     1.0  Orthodox        177.80       180.34         145.0   35.0   27.0
# 3874     0.0  Orthodox        187.96       193.04         258.0   26.0   34.0
#
#       R_eff_STR  B_eff_STR
# 428    1.000000   0.368421
# 2961   0.941176   0.422727
# 4361   0.933333   0.659574
# 4298   0.920455   0.730909
# 4702   0.916667   0.619048
# ...         ...        ...
# 3784   0.142857   0.166667
# 3298   0.095238   0.334951
# 1535   0.090909   0.369565
# 3530   0.000000   0.618529
# 3874   0.000000   0.222222
#
# [3198 rows x 147 columns]
