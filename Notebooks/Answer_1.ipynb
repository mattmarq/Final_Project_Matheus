# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                  R_fighter       B_fighter               Referee        date  \
# 0             Henry Cejudo   Marlon Moraes          Marc Goddard  2019-06-08
# 1     Valentina Shevchenko     Jessica Eye       Robert Madrigal  2019-06-08
# 2            Tony Ferguson  Donald Cerrone       Dan Miragliotta  2019-06-08
# 3            Jimmie Rivera        Petr Yan       Kevin MacDonald  2019-06-08
# 4              Tai Tuivasa   Blagoy Ivanov       Dan Miragliotta  2019-06-08
# ...                    ...             ...                   ...         ...
# 5139        Gerard Gordeau    Kevin Rosier  Joao Alberto Barreto  1993-11-12
# 5140          Ken Shamrock   Patrick Smith  Joao Alberto Barreto  1993-11-12
# 5141          Royce Gracie   Art Jimmerson  Joao Alberto Barreto  1993-11-12
# 5142          Kevin Rosier    Zane Frazier  Joao Alberto Barreto  1993-11-12
# 5143        Gerard Gordeau      Teila Tuli  Joao Alberto Barreto  1993-11-12
#
# ...

# %%
df.isna().sum()
# Out:
# R_fighter         0
# B_fighter         0
# Referee          23
# date              0
# location          0
#                ...
# R_Height_cms      4
# R_Reach_cms     316
# R_Weight_lbs      3
# B_age           172
# R_age            64
# Length: 145, dtype: int64

# %%
df_title = df[df.title_bout == 1]

# %%
df_title
# Out:
#                  R_fighter        B_fighter               Referee        date  \
# 0             Henry Cejudo    Marlon Moraes          Marc Goddard  2019-06-08
# 1     Valentina Shevchenko      Jessica Eye       Robert Madrigal  2019-06-08
# 38          Rose Namajunas  Jessica Andrade          Marc Goddard  2019-05-11
# 86            Max Holloway   Dustin Poirier           Blake Grice  2019-04-13
# 87         Kelvin Gastelum  Israel Adesanya          Marc Goddard  2019-04-13
# ...                    ...              ...                   ...         ...
# 5098            Dan Severn    Dave Beneteau         John McCarthy  1995-04-07
# 5107          Royce Gracie       Dan Severn         John McCarthy  1994-12-16
# 5115          Steve Jennum    Harold Howard         John McCarthy  1994-09-09
# 5121          Royce Gracie    Patrick Smith         John McCarthy  1994-03-11
# 5136          Royce Gracie   Gerard Gordeau  Joao Alberto Barreto  1993-11-12
#
# ...

# %%
df_title_blue = df_title[df_title.Winner == "Blue"]

# %%
df_title_blue = df_title_blue.sort_values(by="B_age", ascending=False)

# %%
df_title_blue
# Out:
#                     R_fighter              B_fighter         Referee  \
# 462              Stipe Miocic         Daniel Cormier    Marc Goddard
# 1455            Luke Rockhold        Michael Bisping   John McCarthy
# 1897           Cain Velasquez        Fabricio Werdum       Herb Dean
# 1932          Anthony Johnson         Daniel Cormier   John McCarthy
# 793           Michael Bisping      Georges St-Pierre   John McCarthy
# ...                       ...                    ...             ...
# 2418            Vitor Miranda  Antonio Carlos Junior       Herb Dean
# 2419  Marcio Alexandre Junior          Warlley Alves  Mario Yamasaki
# 3576             Mauricio Rua              Jon Jones       Herb Dean
# 2542                 Sai Wang           Zhang Lipeng     Jerin Valel
# 2899               Uriah Hall        Kelvin Gastelum       Herb Dean
#
#             date                               location Winner  title_bout  \
# ...

# %%
df_title_red = df_title[df_title.Winner == "Red"]

# %%
df_title_red = df_title_red.sort_values(by="R_age", ascending=False)

# %%
df_title_red
# Out:
#              R_fighter         B_fighter         Referee        date  \
# 4377     Randy Couture   Gabriel Gonzaga       Herb Dean  2007-08-25
# 4458     Randy Couture        Tim Sylvia   John McCarthy  2007-03-03
# 4729     Randy Couture     Vitor Belfort   John McCarthy  2004-08-21
# 640        Yoel Romero     Luke Rockhold    Marc Goddard  2018-02-10
# 4769     Randy Couture        Tito Ortiz   John McCarthy  2003-09-26
# ...                ...               ...             ...         ...
# 2177    Yair Rodriguez  Leonardo Morales  Mario Yamasaki  2014-11-15
# 3027  Robert Whittaker     Bradley Scott  Steve Perceval  2012-12-14
# 5032     Vitor Belfort    Scott Ferrozzo   John McCarthy  1997-02-07
# 5015     Kevin Jackson     Tony Fryklund   John McCarthy  1997-07-27
# 5115      Steve Jennum     Harold Howard   John McCarthy  1994-09-09
#
#                                    location Winner  title_bout  \
# 4377                 Las Vegas, Nevada, USA    Red        True
# ...
